# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import time
import pandas as pd
import keyboard
from matplotlib.animation import FuncAnimation

# %%
data = yf.download("AAPL", start="2026-02-17", end="2026-02-24")
print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2026-02-17  263.880005  266.290009  255.539993  258.049988  58469100
# 2026-02-18  264.350006  266.820007  262.450012  263.600006  34203300
# 2026-02-19  260.579987  264.480011  260.049988  262.600006  30845300
# 2026-02-20  264.579987  264.750000  258.160004  258.970001  42070500
# 2026-02-23  266.179993  269.429993  263.380005  263.489990  37308200

# %%
X = data.index
y1 = data['Close']
y2 = data['High']
plt.figure(figsize=(15, 5))
plt.plot(X, y1, label='Close')
plt.plot(X, y2, label='High')
plt.legend()
plt.show()

# %%
import sys

# %%
ticker = yf.Ticker("MRF.NS")

def animate(i):
    data = ticker.history(period="1d", interval="1m")
    X = data.tail(30).index
    y = data.tail(30)
    plt.cla()
    plt.figure(figsize=(15, 5))
    plt.plot(X, y['Close'], label='Close')
    plt.legend()

try:
    data = ticker.history(period="1d", interval="1m")
    plt.plot(data.tail(30).index, data.tail(30)['Open'], label='Open')
    plt.plot(data.tail(30).index, data.tail(30)['Close'], label='Close')
    plt.show()
except Exception as e:
    print(f"Error fetching data: {e}")

# %%
ticker = ' MRF.NS'
df = yf.download(ticker, start="2025-03-03", end="2026-03-03")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.shape
# Out:
# (247, 5)

# %%
df.describe()
# Out:
# Price           Close           High            Low           Open  \
# Ticker         MRF.NS         MRF.NS         MRF.NS         MRF.NS
# count      247.000000     247.000000     247.000000     247.000000
# mean    142360.342010  143929.755842  140926.677650  142502.615169
# std      13673.911669   13901.586743   13688.576797   13887.786657
# min     102499.171875  105006.104604  101964.659782  102185.868684
# 25%     137799.601562  139488.562796  136193.476237  137984.295877
# 50%     145899.234375  148002.062939  144245.000000  146494.196154
# 75%     151704.484375  153240.444535  150120.539218  152246.977056
# max     162288.578125  163593.537167  160278.657659  161973.590589
#
# Price         Volume
# Ticker        MRF.NS
# count     247.000000
# mean     7409.708502
# std      5752.229774
# min         0.000000
# 25%      4199.500000
# 50%      6054.000000
# 75%      8383.000000
# max     64381.000000

# %%
df.head()
# Out:
# Price               Close           High            Low           Open Volume
# Ticker             MRF.NS         MRF.NS         MRF.NS         MRF.NS MRF.NS
# Date
# 2025-03-03  105006.101562  106025.110183  103862.639055  105335.336893   4599
# 2025-03-04  102499.171875  105006.104604  102191.254773  104736.276399  13881
# 2025-03-05  105640.367188  105797.122154  101964.659782  102185.868684   6770
# 2025-03-06  107627.054688  108081.048132  106333.826257  106828.506101   5969
# 2025-03-07  107035.640625  108480.429082  106834.501909  107332.223897   4698

# %%
plt.figure(figsize=(30, 20))
for i in df.columns:
    col = i[0]
    plt.plot(df.index, df[col], label=col)
plt.legend()
plt.show()

# %%
max_vol = df[df['Volume'] == df['Volume']].max()
max_vol
# Out:
# Price   Ticker
# Close   MRF.NS    162288.578125
# High    MRF.NS    163593.537167
# Low     MRF.NS    160278.657659
# Open    MRF.NS    161973.590589
# Volume  MRF.NS     64381.000000
# dtype: float64
